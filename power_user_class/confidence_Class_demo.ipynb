# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %% [markdown]
# # Description
#
# 1. Import confidence_Class file
# 2. Instantiate object "prospect_confidence"
# 3. Add scenarios to object and save as a dataframe (hierarchical multi-index)

# %%
#1: import the file to calculate cumulative confidence by scenario
import confidence_Class as conf

# %%
#2:
prospect_scenarios = conf.prospect_confidence(verbose =False)

# %%
#3: 

'''note that the list/arrays of scenarios should all be of equal length

 Args:
    areaP90 (array or list): pessimistic area in sqkm
    areaP10 (array or list): optimistic area in sqkm
    pdP90 (array or list): pessimistic power density in MWe/sqkm
    pdP10 (array or list): optimistic power density in MWe/sqkm
    
'''


scenarios_df = prospect_scenarios.add_scenarios([5]*10,\
                                                       np.arange(30,40,1),\
                                                       [200]*10,\
                                                       np.arange(290,300,1))

# %%
scenarios_df.head()
# Out:
#                                             5_30_200_290  \
#                           expected development size (MW)
# Cumulative confidence (%)
# 99                                              0.000000
# 98                                            481.728829
# 97                                            582.858256
# 96                                            657.766452
# 95                                            720.397206
#
#                                             5_31_200_291  \
#                           expected development size (MW)
# Cumulative confidence (%)
# 99                                              0.000000
# 98                                            475.332834
# 97                                            577.128702
# 96                                            652.743219
# 95                                            716.086585
#
#                                             5_32_200_292  \
# ...

# %%
scenario_dfs.loc[:,scenario_dfs.columns.get_level_values(1)=='expected development size (MW)'].plot(figsize = (10,10))
plt.show()
